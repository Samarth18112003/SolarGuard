# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### Installing Libraries

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 18.3 MB/s eta 0:00:00
# ...

# %% [markdown]
# ### Extracted Datset

# %%
# !unzip /content/drive/MyDrive/solar_cracks/solar.v1i.yolov11.zip -d/content/drive/MyDrive/solar_cracks
# Out:
# Streaming output truncated to the last 5000 lines.
#  extracting: /content/drive/MyDrive/solar_cracks/train/images/soiled-198-_jpg.rf.54eef16b427e22b43d1f9a7df370f863.jpg
#  extracting: /content/drive/MyDrive/solar_cracks/train/images/soiled-198-_jpg.rf.b79ed62e053679763c02189ed4b4decf.jpg
#  extracting: /content/drive/MyDrive/solar_cracks/train/images/soiled-198-_jpg.rf.f08f06d79ac75fb895821d8a48ceb7d8.jpg
#  extracting: /content/drive/MyDrive/solar_cracks/train/images/soiled-2-_JPG_jpg.rf.26562fec8090bc63f0dfb515705206ce.jpg
#  extracting: /content/drive/MyDrive/solar_cracks/train/images/soiled-2-_JPG_jpg.rf.2ac796768a8498d3265529c97e20cb9a.jpg
#  extracting: /content/drive/MyDrive/solar_cracks/train/images/soiled-2-_JPG_jpg.rf.361d4605ec5e62483bde7f805dce5fa4.jpg
#  extracting: /content/drive/MyDrive/solar_cracks/train/images/soiled-20-_jpg.rf.237cfdbcd9cbe917cbb68551d6b87e5b.jpg
# ...

# %%
import locale
locale.getpreferredencoding = lambda: "UTF-8"

# %% [markdown]
# ### Creating Yolo v11 Model

# %%
from ultralytics import YOLO
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
model=YOLO('yolo11m.pt')

# %% [markdown]
# ### Training The Model

# %%
model.train(
    data="/content/drive/MyDrive/solar_cracks/data.yaml",
    epochs=70,
    batch=64,
    imgsz=640,
    patience=0   # disables early stopping
)
# Out:
# Ultralytics 8.4.14 🚀 Python-3.12.12 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# ...

# %% [markdown]
# ### Saving The Model

# %%
# !zip -r /content/drive/MyDrive/solar_cracks/runs.zip runs/
# Out:
#   adding: runs/ (stored 0%)
#   adding: runs/detect/ (stored 0%)
#   adding: runs/detect/train/ (stored 0%)
#   adding: runs/detect/train/args.yaml (deflated 53%)
#   adding: runs/detect/train/train_batch0.jpg (deflated 3%)
#   adding: runs/detect/train/results.csv (deflated 62%)
#   adding: runs/detect/train/BoxPR_curve.png (deflated 18%)
#   adding: runs/detect/train/confusion_matrix_normalized.png (deflated 30%)
#   adding: runs/detect/train/train_batch1.jpg (deflated 3%)
#   adding: runs/detect/train/train_batch3301.jpg (deflated 3%)
#   adding: runs/detect/train/weights/ (stored 0%)
#   adding: runs/detect/train/weights/last.pt (deflated 8%)
#   adding: runs/detect/train/weights/best.pt (deflated 8%)
#   adding: runs/detect/train/val_batch0_pred.jpg (deflated 5%)
#   adding: runs/detect/train/val_batch1_pred.jpg (deflated 11%)
#   adding: runs/detect/train/val_batch0_labels.jpg (deflated 6%)
#   adding: runs/detect/train/val_batch1_labels.jpg (deflated 12%)
# ...

# %%
# !unzip '/content/drive/MyDrive/solar_cracks/runs.zip' -d /content
# Out:
# Archive:  /content/drive/MyDrive/solar_cracks/runs.zip
#    creating: /content/runs/
#    creating: /content/runs/detect/
#    creating: /content/runs/detect/train/
#   inflating: /content/runs/detect/train/args.yaml
#   inflating: /content/runs/detect/train/train_batch0.jpg
#   inflating: /content/runs/detect/train/results.csv
#   inflating: /content/runs/detect/train/BoxPR_curve.png
#   inflating: /content/runs/detect/train/confusion_matrix_normalized.png
#   inflating: /content/runs/detect/train/train_batch1.jpg
#   inflating: /content/runs/detect/train/train_batch3301.jpg
#    creating: /content/runs/detect/train/weights/
#   inflating: /content/runs/detect/train/weights/last.pt
#   inflating: /content/runs/detect/train/weights/best.pt
#   inflating: /content/runs/detect/train/val_batch0_pred.jpg
#   inflating: /content/runs/detect/train/val_batch1_pred.jpg
#   inflating: /content/runs/detect/train/val_batch0_labels.jpg
# ...

# %%
from ultralytics import YOLO

# !yolo task=detect mode=val model='/content/runs/detect/train/weights/best.pt' data='/content/drive/MyDrive/solar_cracks/data.yaml'
# Out:
# Ultralytics 8.4.14 🚀 Python-3.12.12 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# YOLO11m summary (fused): 126 layers, 20,031,574 parameters, 0 gradients, 67.7 GFLOPs
# ...
# val: Fast image access ✅ (ping: 0.7±0.4 ms, read: 0.1±0.1 MB/s, size: 66.2 KB)
# val: Scanning /content/drive/MyDrive/solar_cracks/valid/labels.cache... 349 images, 0 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 349/349 66.5Mit/s 0.0s
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 22/22 1.7it/s 12.7s
#                    all        349        453      0.946      0.915      0.939      0.812
#                cracked        192        233      0.996      0.969      0.994      0.881
#                 soiled        175        220      0.896      0.861      0.883      0.744
# Speed: 3.4ms preprocess, 24.3ms inference, 0.0ms loss, 1.4ms postprocess per image
# Results saved to /content/runs/detect/val
# 💡 Learn more at https://docs.ultralytics.com/modes/val

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 33.5 MB/s eta 0:00:00
# ...

# %%
# !yolo task=detect mode=predict model=/content/runs/detect/train/weights/best.pt conf=0.70 source="/content/drive/MyDrive/solar_cracks/test/images"
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# Ultralytics 8.4.14 🚀 Python-3.12.12 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# YOLO11m summary (fused): 126 layers, 20,031,574 parameters, 0 gradients, 67.7 GFLOPs
#
# image 1/172 /content/drive/MyDrive/solar_cracks/test/images/cracked-10-_jpg.rf.1ae70a43ce6105ab6fe6f574146c2d71.jpg: 640x640 1 cracked, 36.7ms
# image 2/172 /content/drive/MyDrive/solar_cracks/test/images/cracked-101-_jpg.rf.70b6924c4571ee113ea9838550bd5452.jpg: 640x640 3 crackeds, 36.8ms
# image 3/172 /content/drive/MyDrive/solar_cracks/test/images/cracked-114-_jpg.rf.cd4acecec3605fa8fbabdcc76174e6ca.jpg: 640x640 2 crackeds, 36.7ms
# ...

# %% [markdown]
# ### Prediction

# %%
import matplotlib.pyplot as plt
from ultralytics import YOLO

# Load trained YOLO model
model = YOLO('/content/runs/detect/train/weights/best.pt')

# Run prediction
results = model('/content/drive/MyDrive/solar_cracks/test/images/cracked-114-_jpg.rf.cd4acecec3605fa8fbabdcc76174e6ca.jpg')

# Annotate and convert BGR to RGB
annotated_image = results[0].plot()
annotated_image = annotated_image[..., ::-1]  # Convert BGR to RGB

# Display
plt.imshow(annotated_image)
plt.axis('off')
plt.show()
# Out:
# image 1/1 /content/drive/MyDrive/solar_cracks/test/images/cracked-114-_jpg.rf.cd4acecec3605fa8fbabdcc76174e6ca.jpg: 640x640 2 crackeds, 35.3ms
# Speed: 3.2ms preprocess, 35.3ms inference, 15.8ms postprocess per image at shape (1, 3, 640, 640)

# %%
import matplotlib.pyplot as plt
from ultralytics import YOLO

# Load trained YOLO model
model = YOLO('/content/best.pt')

# Run prediction
results = model('/content/cracked-52-_jpg.rf.2868e6a8ed201d795406f115d3af3594.jpg')

# Annotate and convert BGR to RGB
annotated_image = results[0].plot()
annotated_image = annotated_image[..., ::-1]  # Convert BGR to RGB

# Display
plt.imshow(annotated_image)
plt.axis('off')
plt.show()
# Out:
# image 1/1 /content/cracked-52-_jpg.rf.2868e6a8ed201d795406f115d3af3594.jpg: 640x640 1 cracked, 1361.3ms
# Speed: 2.5ms preprocess, 1361.3ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 640)

# %%
import matplotlib.pyplot as plt
from ultralytics import YOLO

# Load trained YOLO model
model = YOLO('/content/best.pt')

# Run prediction
results = model('/content/cracked-303-_jpg.rf.ba2afaba8c176f995efe63cd2a0a69dd.jpg')

# Annotate and convert BGR to RGB
annotated_image = results[0].plot()
annotated_image = annotated_image[..., ::-1]  # Convert BGR to RGB

# Display
plt.imshow(annotated_image)
plt.axis('off')
plt.show()
# Out:
# image 1/1 /content/cracked-303-_jpg.rf.ba2afaba8c176f995efe63cd2a0a69dd.jpg: 640x640 1 cracked, 1419.6ms
# Speed: 4.5ms preprocess, 1419.6ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)

# %%
import matplotlib.pyplot as plt
from ultralytics import YOLO

# Load trained YOLO model
model = YOLO('/content/best.pt')

# Run prediction
results = model('/content/soiled-265-_jpg.rf.23e693399fe12fe9c3de86615ef3ecf6.jpg')

# Annotate and convert BGR to RGB
annotated_image = results[0].plot()
annotated_image = annotated_image[..., ::-1]  # Convert BGR to RGB

# Display
plt.imshow(annotated_image)
plt.axis('off')
plt.show()
# Out:
# image 1/1 /content/soiled-265-_jpg.rf.23e693399fe12fe9c3de86615ef3ecf6.jpg: 640x640 1 soiled, 1334.0ms
# Speed: 3.2ms preprocess, 1334.0ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)

# %%
import matplotlib.pyplot as plt
from ultralytics import YOLO

# Load trained YOLO model
model = YOLO('/content/best.pt')

# Run prediction
results = model('/content/soiled-365-_jpg.rf.29da6e9107c91bb9170885033e490105.jpg')

# Annotate and convert BGR to RGB
annotated_image = results[0].plot()
annotated_image = annotated_image[..., ::-1]  # Convert BGR to RGB

# Display
plt.imshow(annotated_image)
plt.axis('off')
plt.show()
# Out:
# image 1/1 /content/soiled-365-_jpg.rf.29da6e9107c91bb9170885033e490105.jpg: 640x640 1 soiled, 1414.6ms
# Speed: 4.6ms preprocess, 1414.6ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)

# %%
import matplotlib.pyplot as plt
from ultralytics import YOLO

# Load trained YOLO model
model = YOLO('/content/best.pt')

# Run prediction
results = model('/content/soiled-487-_jpg.rf.d65f4aa2fcd1ccd0c6a675235cf1a13d.jpg')

# Annotate and convert BGR to RGB
annotated_image = results[0].plot()
annotated_image = annotated_image[..., ::-1]  # Convert BGR to RGB

# Display
plt.imshow(annotated_image)
plt.axis('off')
plt.show()
# Out:
# image 1/1 /content/soiled-487-_jpg.rf.d65f4aa2fcd1ccd0c6a675235cf1a13d.jpg: 640x640 1 soiled, 1357.3ms
# Speed: 3.1ms preprocess, 1357.3ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)

# %% [markdown]
# #Training plotting

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# Path to YOLO F1-score curve image
img_path = '/content/runs/detect/train/BoxF1_curve.png'

# Display the F1-score curve
img = mpimg.imread(img_path)
plt.figure(figsize=(8,8))
plt.imshow(img)
plt.axis('off')
plt.title('F1-score Curve')
plt.show()

# %% [markdown]
# #Confusion Matrix

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# Path to YOLO confusion matrix image
img_path = '/content/runs/detect/train/confusion_matrix.png'

# Display the confusion matrix
img = mpimg.imread(img_path)
plt.figure(figsize=(8,8))
plt.imshow(img)
plt.axis('off')
plt.title('labels')
plt.show()
